# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit-Saswadkar/Transformers/blob/main/Gen_Ai_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Transformers basics

# %%
# !pip install transformers

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')
model = GPT2LMHeadModel.from_pretrained('gpt2-large', pad_token_id = tokenizer.eos_token_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
tokenizer.eos_token_id
# Out:
# 50256

# %%
tokenizer.decode(tokenizer.eos_token_id)
# Out:
# '<|endoftext|>'

# %%
sentence = input("Enter the text Akaaah...:")
# Out:
# Enter the text Akaaah...:Once upon a time theres a kingdom ruled by cruel king. There was a brave boy named Rohit who was a hunter living in the hungle. he wants to become the king of that kingdom for better future of the kingdom

# %%
numeric_ids = tokenizer.encode(sentence, return_tensors = 'pt')

# %%
numeric_ids
# Out:
# tensor([[ 7454,  2402,   257,   640,   262,   411,   257, 13239,  8879,   416,
#          12177,  5822,    13,  1318,   373,   257, 14802,  2933,  3706, 32694,
#            270,   508,   373,   257, 19177,  2877,   287,   262,  9174,   293,
#             13,   339,  3382,   284,  1716,   262,  5822,   286,   326, 13239,
#            329,  1365,  2003,   286,   262, 13239]])

# %%
tokenizer.decode(numeric_ids[0][0])
# Out:
# 'Once'

# %%
result = model.generate( numeric_ids, max_length = 500, num_beams = 5, no_repeat_ngram_size = 2, early_stopping = True)

# %%
result
# Out:
# tensor([[ 7454,  2402,   257,   640,   262,   411,   257, 13239,  8879,   416,
#          12177,  5822,    13,  1318,   373,   257, 14802,  2933,  3706, 32694,
#            270,   508,   373,   257, 19177,  2877,   287,   262,  9174,   293,
#             13,   339,  3382,   284,  1716,   262,  5822,   286,   326, 13239,
#            329,  1365,  2003,   286,   262, 13239,    13,   198,   198,    49,
#           1219,   270,   373,  4642,   287,   257,  1402,  7404,   287,  3794,
#             13,  2399,  2988,   318,   257, 18739,   290,   465,  2802,   257,
#           2156, 22095,    13,  1649,   339,   373,   845,  1862,    11,   465,
#           2988,   373,  2923,   416,   257,  4295,  1489,   283,    13,   679,
#            373,  1364,   284, 41229,   329,  2241,    13,  1881,  1110,    11,
#            339,  1138,   257,  4950,  2576,  3706,   311,  5350,    13,  1375,
#            373,   262,  4957,   286,   257,  5527, 18739,    13,  1119,  3214,
# ...

# %%
tokenizer.decode( result[0], skip_special_tokens = True)
# Out:
# "Once upon a time theres a kingdom ruled by cruel king. There was a brave boy named Rohit who was a hunter living in the hungle. he wants to become the king of that kingdom for better future of the kingdom.\n\nRohit was born in a small village in India. His father is a farmer and his mother a housewife. When he was very young, his father was killed by a wild boar. He was left to fend for himself. One day, he met a beautiful girl named Sita. She was the daughter of a rich farmer. They fell in love and they got married. After a few years, they moved to a big city where they had many children. But one of them got sick and died. The other two children were very sick. So, the father decided to take them to the forest to look for a cure for the sick child. However, when he got there he found out that there was no cure and that the child was dead. Then he went back to his village and told everyone about the death of his son. That's when the people started to hate him and he had to flee from
# ...
